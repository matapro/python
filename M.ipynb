# %% [markdown]
# <a href="https://colab.research.google.com/github/matapro/python/blob/master/M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x={-4,0,4}
import matplotlib.pyplot as plt
plt.plot([-5,-5, 0, 5, 5], [0,15,5,15,0])
plt.axis([-10, 10, -5, 20])
plt.ylabel(['M'])
plt.show()
